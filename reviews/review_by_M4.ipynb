# %% [markdown]
# Log entry for 25/03/26:
#
# Created repository, established folder structure (/data, /scripts, /output, /reviews), invited collaborators.

# %% [markdown]
# Log entry for 29/003/26
#
# I developed a skeletal structure for the main integration script (run_full_analysis_M4.py). As the team leader, my goal is to establish the workflow of the project and itegrate the work of other memebers.
# Before waiting on other team members to be done, I set up the imports to expect 3 files from the other team members. These are data_extraction_M1, data_preparation_M2 and data_analysis_M3.
# Once my team members push their modules, i'll be able to run the main function to check if the data is being processed correctly.
#
# I will continue to monitor the github repository to ensure everyone is placing their scripts in the correct folder so my integration script can read them.
